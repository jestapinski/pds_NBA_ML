# %% [markdown]
# # NBA Predictive Machine Learning Model
# ## Jordan Stapinski (jstapins), Calvin Lui (clui)
# ### Project II - Practical Data Science 67-364 Spring 2018

# %% [markdown]
# ### Conventions on Representations
# For the process of numerically encoding our statistics to be used in a machine learning model, we use the following numerical conventions (more concretely defined in cell one of code)
#
# #### Conferences
# | Conference | Numerical Representation |
# |------------|--------------------------|
# | Eastern    | 0                        |
# | Western    | 1                        |
# #### Divisions
# | Division     | Numerical Representation |
# |--------------|--------------------------|
# | Atlantic     | 0                        |
# | Southeastern | 1                        |
# | Central      | 2                        |
# | Northwestern | 3                        |
# | Southwestern | 4                        |
# | Pacific      | 5                        |
# #### Locations
# | Location | Numerical Representation |
# |----------|--------------------------|
# | Away     | 0                        |
# | Home     | 1                        |
# #### Results
# | Result   | Numerical Representation |
# |----------|--------------------------|
# | Loss     | 0                        |
# | Win      | 1                        |
# #### Season Types
# | Season Type    | Numerical Representation |
# |----------------|--------------------------|
# | Preseason      | 0                        |
# | Regular Season | 1                        |
# | Postseason     | 2                        |
# #### Roles
# | Role     | Numerical Representation |
# |----------|--------------------------|
# | Bench    | 0                        |
# | Starter  | 1                        |
# #### Positions
# | Position       | Numerical Representation |
# |----------------|--------------------------|
# | Point Guard    | 0                        |
# | Guard          | 1                        |
# | Shooting Guard | 2                        |
# | Small Forward  | 3                        |
# | Forward        | 4                        |
# | Power Forward  | 5                        |
# | Center         | 6                        |

# %%
# Data Importing
import matplotlib.pyplot as plt
import numpy as np
import operator
import pandas as pd

# %matplotlib inline

# Defining Constants
PLAYER_CSV_FILE = './nba-enhanced-stats/2017-18_playerBoxScore.csv'
TEAM_CSV_FILE = './nba-enhanced-stats/2017-18_teamBoxScore.csv'
PREVIEW_LEN = 10

# Manual Categorical Mappings for Logical Encoding
teamConf_numeric = {"East": 0, "West": 1}
teamDiv_numeric = {"Atlantic": 0, "Southeast": 1, "Central": 2, "Northwest": 3, "Southwest": 4, "Pacific": 5}
teamLoc_numeric = {"Away": 0, "Home": 1}
teamRslt_numeric = {"Loss": 0, "Win": 1}
seasTyp_numeric = {"Pre": 0, "Regular": 1, "Post": 2}
playStat_numeric = {"Bench": 0, "Starter": 1}
playPos_numeric = {"PG": 0, "G": 1, "SG": 2, "SF": 3, "F": 4, "PF": 5, "C": 6}
# Team Name and Player Name will be One-Hot Encoded

# Possible Columns to Remove for Avoiding Multicollinearity
derived_team_player_cols = ['teamTREB%', 'teamASST%', "teamTS%", "teamEFG%", "teamOREB%", "teamDREB%", "teamTO%", "teamSTL%", "teamBLK%", "teamBLKR", "teamPPS", "teamFIC", "teamFIC40", "teamOrtg", "teamDrtg", "teamEDiff", "teamPlay%", "teamAR", "teamAST/TO", "teamSTL/TO"]
derived_oppt_player_cols = list(map(lambda x: x.replace("team", "oppt"), derived_team_player_cols))

# Referee Names to be Removed
useless_player_cols = ['offLNm1', 'offFNm1', 'offLNm2', 'offFNm2', 'offLNm3', 'offFNm3']

player_cols = ['gmDate', 'gmTime', 'seasTyp', 'playLNm', 'playFNm', 'teamAbbr', 'teamConf', 'teamDiv', 'teamLoc', 'teamRslt', 'teamDayOff', 'offLNm1', 'offFNm1', 'offLNm2', 'offFNm2', 'offLNm3', 'offFNm3', 'playDispNm', 'playStat', 'playMin', 'playPos', 'playHeight', 'playWeight', 'playBDate', 'playPTS', 'playAST', 'playTO', 'playSTL', 'playBLK', 'playPF', 'playFGA', 'playFGM', 'playFG%', 'play2PA', 'play2PM', 'play2P%', 'play3PA', 'play3PM', 'play3P%', 'playFTA', 'playFTM', 'playFT%', 'playORB', 'playDRB', 'playTRB', 'opptAbbr', 'opptConf', 'opptDiv', 'opptLoc', 'opptRslt', 'opptDayOff']
team_cols = ['gmDate', 'gmTime', 'seasTyp', 'offLNm1', 'offFNm1', 'offLNm2', 'offFNm2', 'offLNm3', 'offFNm3', 'teamAbbr', 'teamConf', 'teamDiv', 'teamLoc', 'teamRslt', 'teamMin', 'teamDayOff', 'teamPTS', 'teamAST', 'teamTO', 'teamSTL', 'teamBLK', 'teamPF', 'teamFGA', 'teamFGM', 'teamFG%', 'team2PA', 'team2PM', 'team2P%', 'team3PA', 'team3PM', 'team3P%', 'teamFTA', 'teamFTM', 'teamFT%', 'teamORB', 'teamDRB', 'teamTRB', 'teamPTS1', 'teamPTS2', 'teamPTS3', 'teamPTS4', 'teamPTS5', 'teamPTS6', 'teamPTS7', 'teamPTS8', 'teamTREB%', 'teamASST%', 'teamTS%', 'teamEFG%', 'teamOREB%', 'teamDREB%', 'teamTO%', 'teamSTL%', 'teamBLK%', 'teamBLKR', 'teamPPS', 'teamFIC', 'teamFIC40', 'teamOrtg', 'teamDrtg', 'teamEDiff', 'teamPlay%', 'teamAR', 'teamAST/TO', 'teamSTL/TO', 'opptAbbr', 'opptConf', 'opptDiv', 'opptLoc', 'opptRslt', 'opptMin', 'opptDayOff', 'opptPTS', 'opptAST', 'opptTO', 'opptSTL', 'opptBLK', 'opptPF', 'opptFGA', 'opptFGM', 'opptFG%', 'oppt2PA', 'oppt2PM', 'oppt2P%', 'oppt3PA', 'oppt3PM', 'oppt3P%', 'opptFTA', 'opptFTM', 'opptFT%', 'opptORB', 'opptDRB', 'opptTRB', 'opptPTS1', 'opptPTS2', 'opptPTS3', 'opptPTS4', 'opptPTS5', 'opptPTS6', 'opptPTS7', 'opptPTS8', 'opptTREB%', 'opptASST%', 'opptTS%', 'opptEFG%', 'opptOREB%', 'opptDREB%', 'opptTO%', 'opptSTL%', 'opptBLK%', 'opptBLKR', 'opptPPS', 'opptFIC', 'opptFIC40', 'opptOrtg', 'opptDrtg', 'opptEDiff', 'opptPlay%', 'opptAR', 'opptAST/TO', 'opptSTL/TO', 'poss', 'pace']

player_stats = pd.read_csv(PLAYER_CSV_FILE, sep=',', names=player_cols, encoding='latin-1', skiprows=[0])
team_stats = pd.read_csv(TEAM_CSV_FILE, sep=',', names=team_cols, encoding='latin-1', skiprows=[0])

# %% [markdown]
# ### Data Cleaning
#
# Performing some data cleaning according to the above conventions, as well as removing dashes and colon in dates and times.
#
# Furthermore, we get the stats for each team quickly before training the model.

# %%
# Data Cleaning for team_stats

# Date and Time Formatting
team_stats['gmDate'] = team_stats['gmDate'].apply(lambda x: x.replace("-", ""))
team_stats['gmTime'] = team_stats['gmTime'].apply(lambda x: x.replace(":", ""))

# Categorical Encoding
team_stats['teamConf'] = team_stats['teamConf'].apply(lambda x: teamConf_numeric[x])
team_stats['opptConf'] = team_stats['opptConf'].apply(lambda x: teamConf_numeric[x])
team_stats['teamDiv'] = team_stats['teamDiv'].apply(lambda x: teamDiv_numeric[x])
team_stats['opptDiv'] = team_stats['opptDiv'].apply(lambda x: teamDiv_numeric[x])
team_stats['teamLoc'] = team_stats['teamLoc'].apply(lambda x: teamLoc_numeric[x])
team_stats['opptLoc'] = team_stats['opptLoc'].apply(lambda x: teamLoc_numeric[x])
team_stats['teamRslt'] = team_stats['teamRslt'].apply(lambda x: teamRslt_numeric[x])
team_stats['opptRslt'] = team_stats['opptRslt'].apply(lambda x: teamRslt_numeric[x])
team_stats['seasTyp'] = team_stats['seasTyp'].apply(lambda x: seasTyp_numeric[x])

# One-Hot Encoding
team_stats['teamAbbr'] = team_stats['teamAbbr'].apply(lambda x: "team_" + x)
one_hot_team = pd.get_dummies(team_stats['teamAbbr'])
team_stats = team_stats.join(one_hot_team)

team_stats['opptAbbr'] = team_stats['opptAbbr'].apply(lambda x: "oppt_" + x)
one_hot_oppt_team = pd.get_dummies(team_stats['opptAbbr'])
team_stats = team_stats.join(one_hot_oppt_team)

team_stats = team_stats.drop(['teamAbbr', 'opptAbbr'], axis=1)

# Drop Useless Columns
team_stats = team_stats.drop(useless_player_cols, axis=1)

# Remove Duplicate Rows
team_stats = team_stats.iloc[::2]

# %%
# Note team_stats have two rows for same referee
team_stats.head(PREVIEW_LEN)
# Out:
#       gmDate gmTime  seasTyp  teamConf  teamDiv  teamLoc  teamRslt  teamMin  \
# 0   20171017   0800        1         0        0        0         0      241
# 2   20171017   1030        1         1        4        0         1      239
# 4   20171018   0700        1         0        1        0         0      238
# 6   20171018   0700        1         0        0        0         0      241
# 8   20171018   0700        1         0        1        0         0      240
# 10  20171018   0700        1         0        0        0         0      240
# 12  20171018   0730        1         0        2        0         1      238
# 14  20171018   0800        1         1        4        0         0      240
# 16  20171018   0830        1         0        1        0         1      241
# 18  20171018   0900        1         1        3        0         0      242
#
#     teamDayOff  teamPTS    ...     oppt_OKC  oppt_ORL  oppt_PHI  oppt_PHO  \
# 0            0       99    ...            0         0         0         0
# 2            0      122    ...            0         0         0         0
# 4            0       90    ...            0         0         0         0
# 6            0      131    ...            0         0         0         0
# 8            0      109    ...            0         1         0         0
# 10           0      115    ...            0         0         0         0
# 12           0      108    ...            0         0         0         0
# 14           0       91    ...            0         0         0         0
# 16           0      117    ...            0         0         0         0
# 18           0       96    ...            0         0         0         0
#
#     oppt_POR  oppt_SA  oppt_SAC  oppt_TOR  oppt_UTA  oppt_WAS
# 0          0        0         0         0         0         0
# 2          0        0         0         0         0         0
# 4          0        0         0         0         0         0
# 6          0        0         0         0         0         0
# 8          0        0         0         0         0         0
# 10         0        0         0         0         0         1
# 12         0        0         0         0         0         0
# 14         0        0         0         0         0         0
# 16         0        0         0         0         0         0
# 18         0        0         0         0         1         0
#
# [10 rows x 175 columns]

# %% [markdown]
# ### Additional Data Cleaning
# More data cleaning, for dates, times, etc.

# %%
# Data Cleaning for player_stats

# Date and Time Formatting
player_stats['gmDate'] = player_stats['gmDate'].apply(lambda x: x.replace("-", ""))
player_stats['gmTime'] = player_stats['gmTime'].apply(lambda x: x.replace(":", ""))
player_stats['playBDate'] = player_stats['gmDate'].apply(lambda x: x.replace("-", ""))

# Categorical Encoding
player_stats['teamConf'] = player_stats['teamConf'].apply(lambda x: teamConf_numeric[x])
player_stats['opptConf'] = player_stats['opptConf'].apply(lambda x: teamConf_numeric[x])
player_stats['teamDiv'] = player_stats['teamDiv'].apply(lambda x: teamDiv_numeric[x])
player_stats['opptDiv'] = player_stats['opptDiv'].apply(lambda x: teamDiv_numeric[x])
player_stats['teamLoc'] = player_stats['teamLoc'].apply(lambda x: teamLoc_numeric[x])
player_stats['opptLoc'] = player_stats['opptLoc'].apply(lambda x: teamLoc_numeric[x])
player_stats['teamRslt'] = player_stats['teamRslt'].apply(lambda x: teamRslt_numeric[x])
player_stats['opptRslt'] = player_stats['opptRslt'].apply(lambda x: teamRslt_numeric[x])
player_stats['seasTyp'] = player_stats['seasTyp'].apply(lambda x: seasTyp_numeric[x])
player_stats['playStat'] = player_stats['playStat'].apply(lambda x: playStat_numeric[x])
player_stats['playPos'] = player_stats['playPos'].apply(lambda x: playPos_numeric[x])

# One-Hot Encoding
player_stats['teamAbbr'] = player_stats['teamAbbr'].apply(lambda x: "team_" + x)
one_hot_team = pd.get_dummies(player_stats['teamAbbr'])
player_stats = player_stats.join(one_hot_team)

player_stats['opptAbbr'] = player_stats['opptAbbr'].apply(lambda x: "oppt_" + x)
one_hot_oppt_team = pd.get_dummies(player_stats['opptAbbr'])
player_stats = player_stats.join(one_hot_oppt_team)

one_hot_player = pd.get_dummies(player_stats['playDispNm'])
player_stats = player_stats.join(one_hot_player)

# Drop Processed Columns
player_stats = player_stats.drop(['teamAbbr', 'opptAbbr', 'playDispNm', 'playLNm', 'playFNm'], axis=1)

# Drop Useless Columns
player_stats = player_stats.drop(useless_player_cols, axis=1)

# %%
player_stats.head(PREVIEW_LEN)
# Out:
# ['gmDate',
#  'gmTime',
#  'seasTyp',
#  'teamConf',
#  'teamDiv',
#  'teamLoc',
#  'teamRslt',
#  'teamDayOff',
#  'playStat',
#  'playMin',
#  'playPos',
#  'playHeight',
#  'playWeight',
#  'playBDate',
#  'playPTS',
#  'playAST',
#  'playTO',
#  'playSTL',
#  'playBLK',
#  'playPF',
#  'playFGA',
#  'playFGM',
#  'playFG%',
#  'play2PA',
#  'play2PM',
#  'play2P%',
#  'play3PA',
#  'play3PM',
#  'play3P%',
#  'playFTA',
#  'playFTM',
#  'playFT%',
#  'playORB',
#  'playDRB',
#  'playTRB',
#  'opptConf',
#  'opptDiv',
#  'opptLoc',
#  'opptRslt',
#  'opptDayOff',
#  'team_ATL',
#  'team_BKN',
#  'team_BOS',
#  'team_CHA',
#  'team_CHI',
#  'team_CLE',
#  'team_DAL',
#  'team_DEN',
#  'team_DET',
#  'team_GS',
#  'team_HOU',
#  'team_IND',
#  'team_LAC',
#  'team_LAL',
#  'team_MEM',
#  'team_MIA',
#  'team_MIL',
#  'team_MIN',
#  'team_NO',
#  'team_NY',
#  'team_OKC',
#  'team_ORL',
#  'team_PHI',
#  'team_PHO',
#  'team_POR',
#  'team_SA',
#  'team_SAC',
#  'team_TOR',
#  'team_UTA',
#  'team_WAS',
#  'oppt_ATL',
#  'oppt_BKN',
#  'oppt_BOS',
#  'oppt_CHA',
#  'oppt_CHI',
#  'oppt_CLE',
#  'oppt_DAL',
#  'oppt_DEN',
#  'oppt_DET',
#  'oppt_GS',
#  'oppt_HOU',
#  'oppt_IND',
#  'oppt_LAC',
#  'oppt_LAL',
#  'oppt_MEM',
#  'oppt_MIA',
#  'oppt_MIL',
#  'oppt_MIN',
#  'oppt_NO',
#  'oppt_NY',
#  'oppt_OKC',
#  'oppt_ORL',
#  'oppt_PHI',
#  'oppt_PHO',
#  'oppt_POR',
#  'oppt_SA',
#  'oppt_SAC',
#  'oppt_TOR',
#  'oppt_UTA',
#  'oppt_WAS',
#  'Aaron Brooks',
#  'Aaron Gordon',
#  'Aaron Harrison',
#  'Aaron Jackson',
#  'Abdel Nader',
#  'Adreian Payne',
#  'Al Horford',
#  'Al Jefferson',
#  'Al-Farouq Aminu',
#  'Alan Williams',
#  'Alec Burks',
#  'Alec Peters',
#  'Alex Caruso',
#  'Alex Len',
#  'Alex Poythress',
#  'Alfonzo McKinnie',
#  'Allen Crabbe',
#  'Amir Johnson',
#  'Andre Drummond',
#  'Andre Iguodala',
#  'Andre Ingram',
#  'Andrew Bogut',
#  'Andrew Harrison',
#  'Andrew White',
#  'Andrew Wiggins',
#  'AndrÃ© Roberson',
#  'Ante Å½iÅ¾iÄ\x87',
#  'Anthony Brown',
#  'Anthony Davis',
#  'Anthony Tolliver',
#  'Antonio Blakeney',
#  'Antonius Cleveland',
#  'Aron Baynes',
#  'Arron Afflalo',
#  'Austin Rivers',
#  'Avery Bradley',
#  'Bam Adebayo',
#  'Ben McLemore',
#  'Ben Moore',
#  'Ben Simmons',
#  'Bismack Biyombo',
#  'Blake Griffin',
#  'Boban MarjanoviÄ\x87',
#  'Bobby Brown',
#  'Bobby Portis',
#  'Bogdan Bogdanovic',
#  'Bojan BogdanoviÄ\x87',
#  'Bradley Beal',
#  'Brandan Wright',
#  'Brandon Ingram',
#  'Brandon Jennings',
#  'Brandon Paul',
#  'Briante Weber',
#  'Brice Johnson',
#  'Brook Lopez',
#  'Bruno Caboclo',
#  'Bryn Forbes',
#  'Buddy Hield',
#  'C.J. McCollum',
#  'C.J. Miles',
#  'C.J. Williams',
#  'Caleb Swanigan',
#  'Cameron Payne',
#  'Caris LeVert',
#  'Carmelo Anthony',
#  'Cedi Osman',
#  'Chandler Parsons',
#  'Channing Frye',
#  'Charles Cooke',
#  'Cheick Diallo',
#  'Chinanu Onuaku',
#  'Chris Boucher',
#  'Chris McCullough',
#  'Chris Paul',
#  'Clint Capela',
#  'Cody Zeller',
#  'Cole Aldrich',
#  'Corey Brewer',
#  'Cory Joseph',
#  'Courtney Lee',
#  'Cristiano FelÃ\xadcio',
#  "D'Angelo Russell",
#  'D.J. Augustin',
#  'D.J. Wilson',
#  'Dakari Johnson',
#  'Damian Jones',
#  'Damian Lillard',
#  'Damien Wilkins',
#  'Damion Lee',
#  'Damyean Dotson',
#  'Daniel Hamilton',
#  'Daniel Theis',
#  'Danilo Gallinari',
#  'Danny Green',
#  'Dante Cunningham',
#  'Dante Exum',
#  'Danuel House',
#  'Dario Saric',
#  'Darius Miller',
#  'Darrell Arthur',
#  'Darren Collison',
#  'Darrun Hilliard',
#  'David Nwaba',
#  'David Stockton',
#  'David West',
#  'Davon Reed',
#  "De'Aaron Fox",
#  'DeAndre Jordan',
#  'DeAndre Liggins',
#  'DeAndreâ\x80\x99 Bembry',
#  'DeMar DeRozan',
#  'DeMarcus Cousins',
#  'DeMarre Carroll',
#  'Dejounte Murray',
#  'Delon Wright',
#  'Demetrius Jackson',
#  'Dennis SchrÃ¶der',
#  'Dennis Smith',
#  'Denzel Valentine',
#  'Derrick Favors',
#  'Derrick Jones',
#  'Derrick Rose',
#  'Derrick Walton',
#  'Derrick White',
#  'Derrick Williams',
#  'Devin Booker',
#  'Devin Harris',
#  'Devin Robinson',
#  'Dewayne Dedmon',
#  'Deyonta Davis',
#  'Dillon Brooks',
#  'Dion Waiters',
#  'Dirk Nowitzki',
#  'Domantas Sabonis',
#  'Donovan Mitchell',
#  'Dorian Finney-Smith',
#  'Doug McDermott',
#  'Dragan Bender',
#  'Draymond Green',
#  'Dwayne Bacon',
#  'Dwight Buycks',
#  'Dwight Howard',
#  'Dwight Powell',
#  'Dwyane Wade',
#  'DÄ\x81vis BertÄ\x81ns',
#  "E'Twaun Moore",
#  'Ed Davis',
#  'Edmond Sumner',
#  'Ekpe Udoh',
#  'Elfrid Payton',
#  'Emeka Okafor',
#  'Emmanuel Mudiay',
#  'Enes Kanter',
#  'Eric Bledsoe',
#  'Eric Gordon',
#  'Eric Moreland',
#  'Erik McCree',
#  'Ersan Ilyasova',
#  'Evan Fournier',
#  'Evan Turner',
#  'Frank Kaminsky',
#  'Frank Mason',
#  'Frank Ntilikina',
#  'Fred VanVleet',
#  'Furkan Korkmaz',
#  'Garrett Temple',
#  'Gary Harris',
#  'Gary Payton II',
#  'George Hill',
#  'Georges Niang',
#  'Georgios Papagiannis',
#  'Gerald Green',
#  'Gian Clavell',
#  'Giannis Antetokounmpo',
#  'Glenn Robinson',
#  'Goran DragiÄ\x87',
#  'Gordon Hayward',
#  'Gorgui Dieng',
#  'Greg Monroe',
#  'Guerschon Yabusele',
#  'Harrison Barnes',
#  'Hassan Whiteside',
#  'Henry Ellenson',
#  'Ian Clark',
#  'Ian Mahinmi',
#  'Ike Anigbogu',
#  'Iman Shumpert',
#  'Isaiah Canaan',
#  'Isaiah Hicks',
#  'Isaiah Taylor',
#  'Isaiah Thomas',
#  'Isaiah Whitehead',
#  'Ishmael Smith',
#  'Ivan Rabb',
#  'Ivica Zubac',
#  'J.J. Redick',
#  'J.R. Smith',
#  'JaKarr Sampson',
#  'JaMychal Green',
#  'JaVale McGee',
#  'Jabari Bird',
#  'Jabari Parker',
#  'Jack Cooley',
#  'Jacob Pullen',
#  'Jacob Wiley',
#  'Jae Crowder',
#  'Jahlil Okafor',
#  'Jake Layman',
#  'Jakob PÃ¶ltl',
#  'Jalen Jones',
#  'Jamal Crawford',
#  'Jamal Murray',
#  'Jameel Warney',
#  'Jameer Nelson',
#  'Jamel Artis',
#  'James Ennis',
#  'James Harden',
#  'James Johnson',
#  'James Michael McAdoo',
#  'James Web III',
#  'James Young',
#  'Jamil Wilson',
#  'Jared Dudley',
#  'Jarell Eddie',
#  'Jarell Martin',
#  'Jarrett Allen',
#  'Jarrett Jack',
#  'Jason Smith',
#  'Jason Terry',
#  'Jawun Evans',
#  'Jaylen Brown',
#  'Jaylen Morris',
#  'Jayson Tatum',
#  'Jeff Green',
#  'Jeff Teague',
#  'Jeff Withey',
#  'Jerami Grant',
#  'Jeremy Evans',
#  'Jeremy Lamb',
#  'Jeremy Lin',
#  'Jerian Grant',
#  'Jerryd Bayless',
#  'Jimmy Butler',
#  'Joakim Noah',
#  'Jodie Meeks',
#  'Joe Harris',
#  'Joe Ingles',
#  'Joe Johnson',
#  'Joel Bolomboy',
#  'Joel Embiid',
#  'Joffrey Lauvergne',
#  'John Collins',
#  'John Henson',
#  'John Holland',
#  'John Wall',
#  'Johnathan Motley',
#  "Johnny O'Bryant",
#  'Jon Leuer',
#  'Jonas Jerebko',
#  'Jonas ValanÄ\x8diÅ«nas',
#  'Jonathan Gibson',
#  'Jonathan Isaac',
#  'Jonathon Simmons',
#  'Jordan Bell',
#  'Jordan Clarkson',
#  'Jordan Crawford',
#  'Jordan Mickey',
#  'Jose Barea',
#  'Jose Calderon',
#  'Joseph Young',
#  'Josh Gray',
#  'Josh Hart',
#  'Josh Huestis',
#  'Josh Jackson',
#  'Josh Magette',
#  'Josh McRoberts',
#  'Josh Richardson',
#  'Josh Smith',
#  'Jrue Holiday',
#  'Juan HernangÃ³mez',
#  'Julius Randle',
#  'Julyan Stone',
#  'Justin Anderson',
#  'Justin Holiday',
#  'Justin Jackson',
#  'Justin Patton',
#  'Justise Winslow',
#  'Jusuf Nurkic',
#  'Kadeem Allen',
#  'Karl-Anthony Towns',
#  'Kawhi Leonard',
#  'Kay Felder',
#  'Kelly Olynyk',
#  'Kelly Oubre Jr.',
#  'Kemba Walker',
#  'Kendrick Perkins',
#  'Kenneth Faried',
#  'Kent Bazemore',
#  'Kentavious Caldwell-Pope',
#  'Kevin Durant',
#  'Kevin Love',
#  'Kevon Looney',
#  'Khem Birch',
#  'Khris Middleton',
#  'Klay Thompson',
#  'Kobi Simmons',
#  'Kosta Koufos',
#  'Kris Dunn',
#  'Kristaps PorziÅ\x86Ä£is',
#  'Kyle Anderson',
#  'Kyle Collinsworth',
#  'Kyle Korver',
#  'Kyle Kuzma',
#  'Kyle Lowry',
#  "Kyle O'Quinn",
#  'Kyle Singler',
#  'Kyrie Irving',
#  'LaMarcus Aldridge',
#  'Lance Stephenson',
#  'Lance Thomas',
#  'Langston Galloway',
#  'Larry Drew',
#  'Larry Nance Jr.',
#  'Lauri Markkanen',
#  'LeBron James',
#  'London Perrantes',
#  'Lonzo Ball',
#  'Lorenzo Brown',
#  'Lou Williams',
#  'Luc Richard Mbah a Moute',
#  'Lucas Nogueira',
#  'Luis Montero',
#  'Luke Babbitt',
#  'Luke Kennard',
#  'Luke Kornet',
#  'Luol Deng',
#  'Malachi Richardson',
#  'Malcolm Brogdon',
#  'Malcolm Delaney',
#  'Malcolm Miller',
#  'Malik Beasley',
#  'Malik Monk',
#  'Mangok Mathiang',
#  'Manu GinÃ³bili',
#  'MarShon Brooks',
#  'Marc Gasol',
#  'Marcin Gortat',
#  'Marco Belinelli',
#  'Marcus Georges-Hunt',
#  'Marcus Morris',
#  'Marcus Paige',
#  'Marcus Smart',
#  'Mario Chalmers',
#  'Mario Hezonja',
#  'Markel Brown',
#  'Markelle Fultz',
#  'Markieff Morris',
#  'Marquese Chriss',
#  'Marquis Teague',
#  'Marreese Speights',
#  'Marshall Plumlee',
#  'Marvin Williams',
#  'Mason Plumlee',
#  'Matt Costello',
#  'Matt Williams',
#  'Matthew Dellavedova',
#  'Maxi Kleber',
#  'Meyers Leonard',
#  'Michael Beasley',
#  'Michael Carter-Williams',
#  'Michael Kidd-Gilchrist',
#  'Mike Conley',
#  'Mike James',
#  'Mike Muscala',
#  'Mike Scott',
#  'Miles Plumlee',
#  'Milos Teodosic',
#  'Milton Doyle',
#  'Mindaugas Kuzminskas',
#  'Mirza TeletoviÄ\x87',
#  'Moe Harkless',
#  'Monte Morris',
#  'Montrezl Harrell',
#  'Myke Henry',
#  'Myles Turner',
#  'Nate Wolters',
#  'Nazareth Mitrou-Long',
#  'Nemanja Bjelica',
#  'NenÃª',
#  'Nerlens Noel',
#  'Nick Collison',
#  'Nick Young',
#  'Nicolas Batum',
#  'Nicolas Brussino',
#  'Nigel Hayes',
#  'Nik Stauskas',
#  'Nikola JokiÄ\x87',
#  'Nikola MirotiÄ\x87',
#  'Nikola VuÄ\x8deviÄ\x87',
#  'Noah Vonleh',
#  'Norman Powell',
#  'OG Anunoby',
#  'Okaro White',
#  'Omari Johnson',
#  'Omer Asik',
#  'Omri Casspi',
#  'Otto Porter',
#  'P.J. Dozier',
#  'P.J. Tucker',
#  'Pascal Siakam',
#  'Pat Connaughton',
#  'Patrick Beverley',
#  'Patrick McCaw',
#  'Patrick Mills',
#  'Patrick Patterson',
#  'Pau Gasol',
#  'Paul George',
#  'Paul Millsap',
#  'Paul Zipser',
#  'Quincy Acy',
#  'Quincy Pondexter',
#  'Quinn Cook',
#  'R.J. Hunter',
#  'Rajon Rondo',
#  'Ramon Sessions',
#  'Rashad Vaughn',
#  'Raulzinho Neto',
#  'Raymond Felton',
#  'Reggie Bullock',
#  'Reggie Hearn',
#  'Reggie Jackson',
#  'Richard Jefferson',
#  'Richaun Holmes',
#  'Ricky Rubio',
#  'Robert Covington',
#  'Robin Lopez',
#  'Rodney Hood',
#  'Rodney McGruder',
#  'Rodney Purvis',
#  'Ron Baker',
#  'Rondae Hollis-Jefferson',
#  "Royce O'Neale",
#  'Rudy Gay',
#  'Rudy Gobert',
#  'Russell Westbrook',
#  'Ryan Anderson',
#  'Ryan Arcidiacono',
#  'Salah Mejri',
#  'Sam Dekker',
#  'Scotty Hopson',
#  'Sean Kilpatrick',
#  'Semi Ojeleye',
#  'Serge Ibaka',
#  'Shabazz Muhammad',
#  'Shabazz Napier',
#  'Shane Larkin',
#  'Shaquille Harrison',
#  'Shaun Livingston',
#  'Shelvin Mack',
#  'Sindarius Thornwell',
#  'Skal LabissiÃ¨re',
#  'Solomon Hill',
#  'Spencer Dinwiddie',
#  'Stanley Johnson',
#  'Stephen Curry',
#  'Sterling Brown',
#  'Steven Adams',
#  'T.J. Leaf',
#  'T.J. McConnell',
#  'T.J. Warren',
#  'Taj Gibson',
#  'Tarik Black',
#  'Taurean Prince',
#  'Terrance Ferguson',
#  'Terrence Ross',
#  'Terry Rozier',
#  'Thabo Sefolosha',
#  'Thaddeus Young',
#  'Thomas Bryant',
#  'Thon Maker',
#  'Tim Frazier',
#  'Tim Hardaway Jr.',
#  'Tim Quarterman',
#  'Timofey Mozgov',
#  'TimothÃ© Luwawu-Cabarrot',
#  'Tobias Harris',
#  'TomÃ¡Å¡ SatoranskÃ½',
#  'Tony Allen',
#  'Tony Bradley',
#  'Tony Parker',
#  'Tony Snell',
#  'Torrey Craig',
#  'Travis Wear',
#  'Treveon Graham',
#  'Trevor Ariza',
#  'Trevor Booker',
#  'Trey Burke',
#  'Trey Lyles',
#  'Trey McKinney-Jones',
#  'Tristan Thompson',
#  'Troy Daniels',
#  'Troy Williams',
#  'Tyler Cavanaugh',
#  'Tyler Dorsey',
#  'Tyler Ennis',
#  'Tyler Johnson',
#  'Tyler Lydon',
#  'Tyler Ulis',
#  'Tyler Zeller',
#  'Tyreke Evans',
#  'Tyrone Wallace',
#  'Tyson Chandler',
#  'Tyus Jones',
#  'Udonis Haslem',
#  'Vander Blue',
#  'Victor Oladipo',
#  'Vince Carter',
#  'Vince Hunter',
#  'Wade Baldwin',
#  'Walter Lemon',
#  'Wayne Ellington',
#  'Wayne Selden',
#  'Wes Johnson',
#  'Wesley Iwundu',
#  'Wesley Matthews',
#  'Will Barton',
#  'Willie Cauley-Stein',
#  'Willie Reed',
#  'Willy HernangÃ³mez',
#  'Wilson Chandler',
#  'Xavier Munford',
#  'Xavier Rathan-Mayes',
#  'Xavier Silas',
#  'Yogi Ferrell',
#  'Zach Collins',
#  'Zach LaVine',
#  'Zach Randolph',
#  'Zaza Pachulia',
#  'Zhou Qi',
#  'Ã\x81lex Abrines']

# %% [markdown]
# ## Baseline Predictive Model
# Using a Gradient Boosting Classifier, we achieve a baseline of about 66% accuracy on game outcomes by using the teams playing as our only features. We really wish to bump this metric up as much as possible by better dissecting team and player statistics and then composing hypothetical scenarios not tested in the season.
#
# Note this model doesn't really use any team or player statistics. Later, we will represent the team as a composition of individucal players, which should help in improving our ability to predict games.

# %%
# Predicting Wins only based on Teams Playing
# Can Build Another Model to Predict Points per Team
X = team_stats.drop(list(set(team_cols) - set(useless_player_cols) - set(['teamAbbr', 'opptAbbr'])), axis=1)
y = team_stats.teamRslt

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)

from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score
pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.6585365853658537

# %% [markdown]
# ## Representing the Player
# For representing a single player, we are going to leverage the object-oriented functionality of Python and construct a `Player` class. A player is represented with the following attributes:
# - `name` (the player's name)
# - `ppg` (points per game)
# - `apg` (assists per game)
# - `rpg` (rebounds per game)
# - `spg` (steals per game)
# - `bpg` (blocks per game)
# - `fgapg` (field goals attempted per game)
# - `fgp` (field goal percentage)
# - `ftapg` (free throws attempted per game)
# - `ftp` (free throw percentage)
# - `gp` (games played)
# - `raw_player_df` (dataframe for just this player)
#
# and methods:
# - `to_training_data`: returns a vectorized set of features for this player
# - `stats_vs_specific_team(team_abbrev)`: returns players vectorized stats vs a specific team

# %%
class Player(object):
    def __init__(self, name, ppg, apg, rpg, spg, bpg, fgapg, fgp, ftapg, ftp, gp, raw_player_df):
        self.name = name
        self.ppg = ppg
        self.apg = apg
        self.rpg = rpg
        self.spg = spg
        self.bpg = bpg
        self.fgapg = fgapg
        self.fgp = fgp
        self.ftapg = ftapg
        self.ftp = ftp
# Debating use of below metric
#         self.tpp = tpp
        self.gp = gp
# Debating use of below metric
#         self.mpg = mpg
        self.raw_player_df = raw_player_df
        
    def stats_vs_specific_team(self, team_abbrev):
        pass
        # returns dictionary of funneled down values
        
    def to_training_data(self):
        # Note: Leaving out games played
        return [self.ppg, self.apg, self.rpg, self.spgm, self.bpg, self.fgapg, self.fgp, self.ftapg, self.ftp]

# Get List of players
num_non_player_cols = 100
players_registered = player_stats.columns.tolist()[num_non_player_cols:]

# Helper functions to calculate statistics (per game, per season for certain ones)
def calculate_per_game(stat):
    mins_per_game = 48
    total_games = (specific_player['playMin'].sum()) / mins_per_game
    return stat / total_games   

def calculate_ppg(specific_player):
    total_points = specific_player['playPTS'].sum()
    return calculate_per_game(total_points)

def calculate_apg(specific_player):
    total_assists = specific_player['playAST'].sum()
    return calculate_per_game(total_assists)

def calculate_trb(specific_player):
    total_rebounds = specific_player['playTRB'].sum()
    return calculate_per_game(total_rebounds)

def calculate_spg(specific_player):
    total_steals = specific_player['playSTL'].sum()
    return calculate_per_game(total_steals)

def calculate_bpg(specific_player):
    total_blocks = specific_player['playBLK'].sum()
    return calculate_per_game(total_blocks)

# Field goal attempts per game
def calculate_fgapg(specific_player):
    total_fga = specific_player['playFGA'].sum()
    return calculate_per_game(total_fga)

# Field goals percentage made per game
def calculate_fgp(specific_player):
    return specific_player['playFG%'].mean()

# Free throw attempts per game
def calculate_ftapg(specific_player):
    total_fta = specific_player['playFTA'].sum()
    return calculate_per_game(total_fta)

# Free throw percentage per game
def calculate_ftp(specific_player):
    return specific_player['playFT%'].mean()

all_stats = {}
for player in players_registered:
    specific_player = player_stats[player_stats[player] == 1]
    ppg = calculate_ppg(specific_player)
    apg = calculate_apg(specific_player)
    trb = calculate_trb(specific_player)
    spg = calculate_spg(specific_player)
    bpg = calculate_bpg(specific_player)
    fgapg = calculate_fgapg(specific_player)
    fgp = calculate_fgp(specific_player)
    ftapg = calculate_ftapg(specific_player)
    ftp = calculate_ftp(specific_player)
    gp = len(specific_player)
    name = player
    all_stats[player] = Player(name, ppg, apg, trb, spg, bpg, fgapg, fgp, ftapg, ftp, gp, specific_player)

all_stats
# Out:
# {'Aaron Brooks': <__main__.Player at 0x1a0f926550>,
#  'Aaron Gordon': <__main__.Player at 0x1a0f9267b8>,
#  'Aaron Harrison': <__main__.Player at 0x1a0f926a90>,
#  'Aaron Jackson': <__main__.Player at 0x1a0f926d68>,
#  'Abdel Nader': <__main__.Player at 0x1a0f9350b8>,
#  'Adreian Payne': <__main__.Player at 0x1a0f935358>,
#  'Al Horford': <__main__.Player at 0x1a0f935630>,
#  'Al Jefferson': <__main__.Player at 0x1a0f935908>,
#  'Al-Farouq Aminu': <__main__.Player at 0x1a0f935be0>,
#  'Alan Williams': <__main__.Player at 0x1a0f935eb8>,
#  'Alec Burks': <__main__.Player at 0x1a0f9251d0>,
#  'Alec Peters': <__main__.Player at 0x1a0f9254a8>,
#  'Alex Caruso': <__main__.Player at 0x1a0f925780>,
#  'Alex Len': <__main__.Player at 0x1a0f925a58>,
#  'Alex Poythress': <__main__.Player at 0x1a0f925d30>,
#  'Alfonzo McKinnie': <__main__.Player at 0x1a0f93f048>,
#  'Allen Crabbe': <__main__.Player at 0x1a0f93f320>,
#  'Amir Johnson': <__main__.Player at 0x1a0f93f5f8>,
#  'Andre Drummond': <__main__.Player at 0x1a0f93f8d0>,
#  'Andre Iguodala': <__main__.Player at 0x1a0f93fba8>,
#  'Andre Ingram': <__main__.Player at 0x1a0f93fe80>,
#  'Andrew Bogut': <__main__.Player at 0x1a0f94c198>,
#  'Andrew Harrison': <__main__.Player at 0x1a0f94c470>,
#  'Andrew White': <__main__.Player at 0x1a0f94c748>,
#  'Andrew Wiggins': <__main__.Player at 0x1a0f94ca20>,
#  'AndrÃ© Roberson': <__main__.Player at 0x1a0f94ccf8>,
#  'Ante Å½iÅ¾iÄ\x87': <__main__.Player at 0x1a0f958048>,
#  'Anthony Brown': <__main__.Player at 0x1a0f9582e8>,
#  'Anthony Davis': <__main__.Player at 0x1a0f9585c0>,
#  'Anthony Tolliver': <__main__.Player at 0x1a0f958898>,
#  'Antonio Blakeney': <__main__.Player at 0x1a0f958b70>,
#  'Antonius Cleveland': <__main__.Player at 0x1a0f958e48>,
#  'Aron Baynes': <__main__.Player at 0x1a0f966160>,
#  'Arron Afflalo': <__main__.Player at 0x1a0f966438>,
#  'Austin Rivers': <__main__.Player at 0x1a0f966710>,
#  'Avery Bradley': <__main__.Player at 0x1a0f9669e8>,
#  'Bam Adebayo': <__main__.Player at 0x1a0f966cc0>,
#  'Ben McLemore': <__main__.Player at 0x1a0f966f98>,
#  'Ben Moore': <__main__.Player at 0x1a0f9742b0>,
#  'Ben Simmons': <__main__.Player at 0x1a0f974588>,
#  'Bismack Biyombo': <__main__.Player at 0x1a0f974860>,
#  'Blake Griffin': <__main__.Player at 0x1a0f974b38>,
#  'Boban MarjanoviÄ\x87': <__main__.Player at 0x1a0f974e10>,
#  'Bobby Brown': <__main__.Player at 0x1a0f981128>,
#  'Bobby Portis': <__main__.Player at 0x1a0f981400>,
#  'Bogdan Bogdanovic': <__main__.Player at 0x1a0f9816d8>,
#  'Bojan BogdanoviÄ\x87': <__main__.Player at 0x1a0f9819b0>,
#  'Bradley Beal': <__main__.Player at 0x1a0f981c88>,
#  'Brandan Wright': <__main__.Player at 0x1a0f981f60>,
#  'Brandon Ingram': <__main__.Player at 0x1a0f98f278>,
#  'Brandon Jennings': <__main__.Player at 0x1a0f98f550>,
#  'Brandon Paul': <__main__.Player at 0x1a0f98f828>,
#  'Briante Weber': <__main__.Player at 0x1a0f98fb00>,
#  'Brice Johnson': <__main__.Player at 0x1a0f98fdd8>,
#  'Brook Lopez': <__main__.Player at 0x1a0f99f0f0>,
#  'Bruno Caboclo': <__main__.Player at 0x1a0f99f3c8>,
#  'Bryn Forbes': <__main__.Player at 0x1a0f99f6a0>,
#  'Buddy Hield': <__main__.Player at 0x1a0f99f978>,
#  'C.J. McCollum': <__main__.Player at 0x1a0f99fc50>,
#  'C.J. Miles': <__main__.Player at 0x1a0f99ff28>,
#  'C.J. Williams': <__main__.Player at 0x1a0f9ac240>,
#  'Caleb Swanigan': <__main__.Player at 0x1a0f9ac518>,
#  'Cameron Payne': <__main__.Player at 0x1a0f9ac7f0>,
#  'Caris LeVert': <__main__.Player at 0x1a0f9acac8>,
#  'Carmelo Anthony': <__main__.Player at 0x1a0f9acda0>,
#  'Cedi Osman': <__main__.Player at 0x1a0f9b80b8>,
#  'Chandler Parsons': <__main__.Player at 0x1a0f9b8390>,
#  'Channing Frye': <__main__.Player at 0x1a0f9b8668>,
#  'Charles Cooke': <__main__.Player at 0x1a0f9b8940>,
#  'Cheick Diallo': <__main__.Player at 0x1a0f9b8c18>,
#  'Chinanu Onuaku': <__main__.Player at 0x1a0f9b8ef0>,
#  'Chris Boucher': <__main__.Player at 0x1a0f9c6208>,
#  'Chris McCullough': <__main__.Player at 0x1a0f9c64e0>,
#  'Chris Paul': <__main__.Player at 0x1a0f9c67b8>,
#  'Clint Capela': <__main__.Player at 0x1a0f9c6a90>,
#  'Cody Zeller': <__main__.Player at 0x1a0f9c6d68>,
#  'Cole Aldrich': <__main__.Player at 0x1a0f9d5080>,
#  'Corey Brewer': <__main__.Player at 0x1a0f9d5358>,
#  'Cory Joseph': <__main__.Player at 0x1a0f9d5630>,
#  'Courtney Lee': <__main__.Player at 0x1a0f9d5908>,
#  'Cristiano FelÃ\xadcio': <__main__.Player at 0x1a0f9d5be0>,
#  "D'Angelo Russell": <__main__.Player at 0x1a0f9d5eb8>,
#  'D.J. Augustin': <__main__.Player at 0x1a0f9e21d0>,
#  'D.J. Wilson': <__main__.Player at 0x1a0f9e24a8>,
#  'Dakari Johnson': <__main__.Player at 0x1a0f9e2780>,
#  'Damian Jones': <__main__.Player at 0x1a0f9e2a58>,
#  'Damian Lillard': <__main__.Player at 0x1a0f9e2d30>,
#  'Damien Wilkins': <__main__.Player at 0x1a0f9ef048>,
#  'Damion Lee': <__main__.Player at 0x1a0f9ef320>,
#  'Damyean Dotson': <__main__.Player at 0x1a0f9ef5f8>,
#  'Daniel Hamilton': <__main__.Player at 0x1a0f9ef8d0>,
#  'Daniel Theis': <__main__.Player at 0x1a0f9efba8>,
#  'Danilo Gallinari': <__main__.Player at 0x1a0f9efe80>,
#  'Danny Green': <__main__.Player at 0x1a0f9fd198>,
#  'Dante Cunningham': <__main__.Player at 0x1a0f9fd470>,
#  'Dante Exum': <__main__.Player at 0x1a0f9fd748>,
#  'Danuel House': <__main__.Player at 0x1a0f9fda20>,
#  'Dario Saric': <__main__.Player at 0x1a0f9fdcf8>,
#  'Darius Miller': <__main__.Player at 0x1a0fa0b048>,
#  'Darrell Arthur': <__main__.Player at 0x1a0fa0b2e8>,
#  'Darren Collison': <__main__.Player at 0x1a0fa0b5c0>,
#  'Darrun Hilliard': <__main__.Player at 0x1a0fa0b898>,
#  'David Nwaba': <__main__.Player at 0x1a0fa0bb70>,
#  'David Stockton': <__main__.Player at 0x1a0fa0be48>,
#  'David West': <__main__.Player at 0x1a0fa18160>,
#  'Davon Reed': <__main__.Player at 0x1a0fa18438>,
#  "De'Aaron Fox": <__main__.Player at 0x1a0fa18710>,
#  'DeAndre Jordan': <__main__.Player at 0x1a0fa189e8>,
#  'DeAndre Liggins': <__main__.Player at 0x1a0fa18cc0>,
#  'DeAndreâ\x80\x99 Bembry': <__main__.Player at 0x1a0fa18f98>,
#  'DeMar DeRozan': <__main__.Player at 0x1a0fa262b0>,
#  'DeMarcus Cousins': <__main__.Player at 0x1a0fa26588>,
#  'DeMarre Carroll': <__main__.Player at 0x1a0fa26860>,
#  'Dejounte Murray': <__main__.Player at 0x1a0fa26b38>,
#  'Delon Wright': <__main__.Player at 0x1a0fa26e10>,
#  'Demetrius Jackson': <__main__.Player at 0x1a0fa34128>,
#  'Dennis SchrÃ¶der': <__main__.Player at 0x1a0fa34400>,
#  'Dennis Smith': <__main__.Player at 0x1a0fa346d8>,
#  'Denzel Valentine': <__main__.Player at 0x1a0fa349b0>,
#  'Derrick Favors': <__main__.Player at 0x1a0fa34c88>,
#  'Derrick Jones': <__main__.Player at 0x1a0fa34f60>,
#  'Derrick Rose': <__main__.Player at 0x1a0fa42278>,
#  'Derrick Walton': <__main__.Player at 0x1a0fa42550>,
#  'Derrick White': <__main__.Player at 0x1a0fa42828>,
#  'Derrick Williams': <__main__.Player at 0x1a0fa42b00>,
#  'Devin Booker': <__main__.Player at 0x1a0fa42dd8>,
#  'Devin Harris': <__main__.Player at 0x1a0fa510f0>,
#  'Devin Robinson': <__main__.Player at 0x1a0fa513c8>,
#  'Dewayne Dedmon': <__main__.Player at 0x1a0fa516a0>,
#  'Deyonta Davis': <__main__.Player at 0x1a0fa51978>,
#  'Dillon Brooks': <__main__.Player at 0x1a0fa51c50>,
#  'Dion Waiters': <__main__.Player at 0x1a0fa51f28>,
#  'Dirk Nowitzki': <__main__.Player at 0x1a0fa5d240>,
#  'Domantas Sabonis': <__main__.Player at 0x1a0fa5d518>,
#  'Donovan Mitchell': <__main__.Player at 0x1a0fa5d7f0>,
#  'Dorian Finney-Smith': <__main__.Player at 0x1a0fa5dac8>,
#  'Doug McDermott': <__main__.Player at 0x1a0fa5dda0>,
#  'Dragan Bender': <__main__.Player at 0x1a0fa6b0b8>,
#  'Draymond Green': <__main__.Player at 0x1a0fa6b390>,
#  'Dwayne Bacon': <__main__.Player at 0x1a0fa6b668>,
#  'Dwight Buycks': <__main__.Player at 0x1a0fa6b940>,
#  'Dwight Howard': <__main__.Player at 0x1a0fa6bc18>,
#  'Dwight Powell': <__main__.Player at 0x1a0fa6bef0>,
#  'Dwyane Wade': <__main__.Player at 0x1a0fa78208>,
#  'DÄ\x81vis BertÄ\x81ns': <__main__.Player at 0x1a0fa784e0>,
#  "E'Twaun Moore": <__main__.Player at 0x1a0fa787b8>,
#  'Ed Davis': <__main__.Player at 0x1a0fa78a90>,
#  'Edmond Sumner': <__main__.Player at 0x1a0fa78d68>,
#  'Ekpe Udoh': <__main__.Player at 0x1a0fa87080>,
#  'Elfrid Payton': <__main__.Player at 0x1a0fa87358>,
#  'Emeka Okafor': <__main__.Player at 0x1a0fa87630>,
#  'Emmanuel Mudiay': <__main__.Player at 0x1a0fa87908>,
#  'Enes Kanter': <__main__.Player at 0x1a0fa87be0>,
#  'Eric Bledsoe': <__main__.Player at 0x1a0fa87eb8>,
#  'Eric Gordon': <__main__.Player at 0x1a0fa931d0>,
#  'Eric Moreland': <__main__.Player at 0x1a0fa934a8>,
#  'Erik McCree': <__main__.Player at 0x1a0fa93780>,
#  'Ersan Ilyasova': <__main__.Player at 0x1a0fa93a58>,
#  'Evan Fournier': <__main__.Player at 0x1a0fa93d30>,
#  'Evan Turner': <__main__.Player at 0x1a0faa2048>,
#  'Frank Kaminsky': <__main__.Player at 0x1a0faa2320>,
#  'Frank Mason': <__main__.Player at 0x1a0faa25f8>,
#  'Frank Ntilikina': <__main__.Player at 0x1a0faa28d0>,
#  'Fred VanVleet': <__main__.Player at 0x1a0faa2ba8>,
#  'Furkan Korkmaz': <__main__.Player at 0x1a0faa2e80>,
#  'Garrett Temple': <__main__.Player at 0x1a0fab0198>,
#  'Gary Harris': <__main__.Player at 0x1a0fab0470>,
#  'Gary Payton II': <__main__.Player at 0x1a0fab0748>,
#  'George Hill': <__main__.Player at 0x1a0fab0a20>,
#  'Georges Niang': <__main__.Player at 0x1a0fab0cf8>,
#  'Georgios Papagiannis': <__main__.Player at 0x1a0fabd048>,
#  'Gerald Green': <__main__.Player at 0x1a0fabd2e8>,
#  'Gian Clavell': <__main__.Player at 0x1a0fabd5c0>,
#  'Giannis Antetokounmpo': <__main__.Player at 0x1a0fabd898>,
#  'Glenn Robinson': <__main__.Player at 0x1a0fabdb70>,
#  'Goran DragiÄ\x87': <__main__.Player at 0x1a0fabde48>,
#  'Gordon Hayward': <__main__.Player at 0x1a0faca160>,
#  'Gorgui Dieng': <__main__.Player at 0x1a0faca438>,
#  'Greg Monroe': <__main__.Player at 0x1a0faca710>,
#  'Guerschon Yabusele': <__main__.Player at 0x1a0faca9e8>,
#  'Harrison Barnes': <__main__.Player at 0x1a0facacc0>,
#  'Hassan Whiteside': <__main__.Player at 0x1a0facaf98>,
#  'Henry Ellenson': <__main__.Player at 0x1a0fad82b0>,
#  'Ian Clark': <__main__.Player at 0x1a0fad8588>,
#  'Ian Mahinmi': <__main__.Player at 0x1a0fad8860>,
#  'Ike Anigbogu': <__main__.Player at 0x1a0fad8b38>,
#  'Iman Shumpert': <__main__.Player at 0x1a0fad8e10>,
#  'Isaiah Canaan': <__main__.Player at 0x1a0fae6128>,
#  'Isaiah Hicks': <__main__.Player at 0x1a0fae6400>,
#  'Isaiah Taylor': <__main__.Player at 0x1a0fae66d8>,
#  'Isaiah Thomas': <__main__.Player at 0x1a0fae69b0>,
#  'Isaiah Whitehead': <__main__.Player at 0x1a0fae6c88>,
#  'Ishmael Smith': <__main__.Player at 0x1a0fae6f60>,
#  'Ivan Rabb': <__main__.Player at 0x1a0faf4278>,
#  'Ivica Zubac': <__main__.Player at 0x1a0faf4550>,
#  'J.J. Redick': <__main__.Player at 0x1a0faf4828>,
#  'J.R. Smith': <__main__.Player at 0x1a0faf4b00>,
#  'JaKarr Sampson': <__main__.Player at 0x1a0faf4dd8>,
#  'JaMychal Green': <__main__.Player at 0x1a0fb020f0>,
#  'JaVale McGee': <__main__.Player at 0x1a0fb023c8>,
#  'Jabari Bird': <__main__.Player at 0x1a0fb026a0>,
#  'Jabari Parker': <__main__.Player at 0x1a0fb02978>,
#  'Jack Cooley': <__main__.Player at 0x1a0fb02c50>,
#  'Jacob Pullen': <__main__.Player at 0x1a0fb02f28>,
#  'Jacob Wiley': <__main__.Player at 0x1a0fb10240>,
#  'Jae Crowder': <__main__.Player at 0x1a0fb10518>,
#  'Jahlil Okafor': <__main__.Player at 0x1a0fb107f0>,
#  'Jake Layman': <__main__.Player at 0x1a0fb10ac8>,
#  'Jakob PÃ¶ltl': <__main__.Player at 0x1a0fb10da0>,
#  'Jalen Jones': <__main__.Player at 0x1a0fb1d0b8>,
#  'Jamal Crawford': <__main__.Player at 0x1a0fb1d390>,
#  'Jamal Murray': <__main__.Player at 0x1a0fb1d668>,
#  'Jameel Warney': <__main__.Player at 0x1a0fb1d940>,
#  'Jameer Nelson': <__main__.Player at 0x1a0fb1dc18>,
#  'Jamel Artis': <__main__.Player at 0x1a0fb1def0>,
#  'James Ennis': <__main__.Player at 0x1a0fb2b208>,
#  'James Harden': <__main__.Player at 0x1a0fb2b4e0>,
#  'James Johnson': <__main__.Player at 0x1a0fb2b7b8>,
#  'James Michael McAdoo': <__main__.Player at 0x1a0fb2ba90>,
#  'James Web III': <__main__.Player at 0x1a0fb2bd68>,
#  'James Young': <__main__.Player at 0x1a0fb3b080>,
#  'Jamil Wilson': <__main__.Player at 0x1a0fb3b358>,
#  'Jared Dudley': <__main__.Player at 0x1a0fb3b630>,
#  'Jarell Eddie': <__main__.Player at 0x1a0fb3b908>,
#  'Jarell Martin': <__main__.Player at 0x1a0fb3bbe0>,
#  'Jarrett Allen': <__main__.Player at 0x1a0fb3beb8>,
#  'Jarrett Jack': <__main__.Player at 0x1a0fb481d0>,
#  'Jason Smith': <__main__.Player at 0x1a0fb484a8>,
#  'Jason Terry': <__main__.Player at 0x1a0fb48780>,
#  'Jawun Evans': <__main__.Player at 0x1a0fb48a58>,
#  'Jaylen Brown': <__main__.Player at 0x1a0fb48d30>,
#  'Jaylen Morris': <__main__.Player at 0x1a0fb56048>,
#  'Jayson Tatum': <__main__.Player at 0x1a0fb56320>,
#  'Jeff Green': <__main__.Player at 0x1a0fb565f8>,
#  'Jeff Teague': <__main__.Player at 0x1a0fb568d0>,
#  'Jeff Withey': <__main__.Player at 0x1a0fb56ba8>,
#  'Jerami Grant': <__main__.Player at 0x1a0fb56e80>,
#  'Jeremy Evans': <__main__.Player at 0x1a0fb64198>,
#  'Jeremy Lamb': <__main__.Player at 0x1a0fb64470>,
#  'Jeremy Lin': <__main__.Player at 0x1a0fb64748>,
#  'Jerian Grant': <__main__.Player at 0x1a0fb64a20>,
#  'Jerryd Bayless': <__main__.Player at 0x1a0fb64cf8>,
#  'Jimmy Butler': <__main__.Player at 0x1a0fb73048>,
#  'Joakim Noah': <__main__.Player at 0x1a0fb732e8>,
#  'Jodie Meeks': <__main__.Player at 0x1a0fb735c0>,
#  'Joe Harris': <__main__.Player at 0x1a0fb73898>,
#  'Joe Ingles': <__main__.Player at 0x1a0fb73b70>,
#  'Joe Johnson': <__main__.Player at 0x1a0fb73e48>,
#  'Joel Bolomboy': <__main__.Player at 0x1a0fb80160>,
#  'Joel Embiid': <__main__.Player at 0x1a0fb80438>,
#  'Joffrey Lauvergne': <__main__.Player at 0x1a0fb80710>,
#  'John Collins': <__main__.Player at 0x1a0fb809e8>,
#  'John Henson': <__main__.Player at 0x1a0fb80cc0>,
#  'John Holland': <__main__.Player at 0x1a0fb80f98>,
#  'John Wall': <__main__.Player at 0x1a0fb8e2b0>,
#  'Johnathan Motley': <__main__.Player at 0x1a0fb8e588>,
#  "Johnny O'Bryant": <__main__.Player at 0x1a0fb8e860>,
#  'Jon Leuer': <__main__.Player at 0x1a0fb8eb38>,
#  'Jonas Jerebko': <__main__.Player at 0x1a0fb8ee10>,
#  'Jonas ValanÄ\x8diÅ«nas': <__main__.Player at 0x1a0fb9e128>,
#  'Jonathan Gibson': <__main__.Player at 0x1a0fb9e400>,
#  'Jonathan Isaac': <__main__.Player at 0x1a0fb9e6d8>,
#  'Jonathon Simmons': <__main__.Player at 0x1a0fb9e9b0>,
#  'Jordan Bell': <__main__.Player at 0x1a0fb9ec88>,
#  'Jordan Clarkson': <__main__.Player at 0x1a0fb9ef60>,
#  'Jordan Crawford': <__main__.Player at 0x1a0fbad278>,
#  'Jordan Mickey': <__main__.Player at 0x1a0fbad550>,
#  'Jose Barea': <__main__.Player at 0x1a0fbad828>,
#  'Jose Calderon': <__main__.Player at 0x1a0fbadb00>,
#  'Joseph Young': <__main__.Player at 0x1a0fbaddd8>,
#  'Josh Gray': <__main__.Player at 0x1a0fbbb0f0>,
#  'Josh Hart': <__main__.Player at 0x1a0fbbb3c8>,
#  'Josh Huestis': <__main__.Player at 0x1a0fbbb6a0>,
#  'Josh Jackson': <__main__.Player at 0x1a0fbbb978>,
#  'Josh Magette': <__main__.Player at 0x1a0fbbbc50>,
#  'Josh McRoberts': <__main__.Player at 0x1a0fbbbf28>,
#  'Josh Richardson': <__main__.Player at 0x1a0fbca240>,
#  'Josh Smith': <__main__.Player at 0x1a0fbca518>,
#  'Jrue Holiday': <__main__.Player at 0x1a0fbca7f0>,
#  'Juan HernangÃ³mez': <__main__.Player at 0x1a0fbcaac8>,
#  'Julius Randle': <__main__.Player at 0x1a0fbcada0>,
#  'Julyan Stone': <__main__.Player at 0x1a0fbd70b8>,
#  'Justin Anderson': <__main__.Player at 0x1a0fbd7390>,
#  'Justin Holiday': <__main__.Player at 0x1a0fbd7668>,
#  'Justin Jackson': <__main__.Player at 0x1a0fbd7940>,
#  'Justin Patton': <__main__.Player at 0x1a0fbd7c18>,
#  'Justise Winslow': <__main__.Player at 0x1a0fbd7ef0>,
#  'Jusuf Nurkic': <__main__.Player at 0x1a0fbe6208>,
#  'Kadeem Allen': <__main__.Player at 0x1a0fbe64e0>,
#  'Karl-Anthony Towns': <__main__.Player at 0x1a0fbe67b8>,
#  'Kawhi Leonard': <__main__.Player at 0x1a0fbe6a90>,
#  'Kay Felder': <__main__.Player at 0x1a0f32b6d8>,
#  'Kelly Olynyk': <__main__.Player at 0x1a0f32b5c0>,
#  'Kelly Oubre Jr.': <__main__.Player at 0x1a0fbe6d30>,
#  'Kemba Walker': <__main__.Player at 0x1a0fbf1048>,
#  'Kendrick Perkins': <__main__.Player at 0x1a0fbf1320>,
#  'Kenneth Faried': <__main__.Player at 0x1a0fbf15f8>,
#  'Kent Bazemore': <__main__.Player at 0x1a0fbf18d0>,
#  'Kentavious Caldwell-Pope': <__main__.Player at 0x1a0fbf1ba8>,
#  'Kevin Durant': <__main__.Player at 0x1a0fbf1e80>,
#  'Kevin Love': <__main__.Player at 0x1a0fbff198>,
#  'Kevon Looney': <__main__.Player at 0x1a0fbff470>,
#  'Khem Birch': <__main__.Player at 0x1a0fbff748>,
#  'Khris Middleton': <__main__.Player at 0x1a0fbffa20>,
#  'Klay Thompson': <__main__.Player at 0x1a0fbffcf8>,
#  'Kobi Simmons': <__main__.Player at 0x1a0fc0e048>,
#  'Kosta Koufos': <__main__.Player at 0x1a0fc0e2e8>,
#  'Kris Dunn': <__main__.Player at 0x1a0fc0e5c0>,
#  'Kristaps PorziÅ\x86Ä£is': <__main__.Player at 0x1a0fc0e898>,
#  'Kyle Anderson': <__main__.Player at 0x1a0fc0eb70>,
#  'Kyle Collinsworth': <__main__.Player at 0x1a0fc0ee48>,
#  'Kyle Korver': <__main__.Player at 0x1a0fc1c160>,
#  'Kyle Kuzma': <__main__.Player at 0x1a0fc1c438>,
#  'Kyle Lowry': <__main__.Player at 0x1a0fc1c710>,
#  "Kyle O'Quinn": <__main__.Player at 0x1a0fc1c9e8>,
#  'Kyle Singler': <__main__.Player at 0x1a0fc1ccc0>,
#  'Kyrie Irving': <__main__.Player at 0x1a0fc1cf98>,
#  'LaMarcus Aldridge': <__main__.Player at 0x1a0fc2a2b0>,
#  'Lance Stephenson': <__main__.Player at 0x1a0fc2a588>,
#  'Lance Thomas': <__main__.Player at 0x1a0fc2a860>,
#  'Langston Galloway': <__main__.Player at 0x1a0fc2ab38>,
#  'Larry Drew': <__main__.Player at 0x1a0fc2ae10>,
#  'Larry Nance Jr.': <__main__.Player at 0x1a0fc39128>,
#  'Lauri Markkanen': <__main__.Player at 0x1a0fc39400>,
#  'LeBron James': <__main__.Player at 0x1a0fc396d8>,
#  'London Perrantes': <__main__.Player at 0x1a0fc399b0>,
#  'Lonzo Ball': <__main__.Player at 0x1a0fc39c88>,
#  'Lorenzo Brown': <__main__.Player at 0x1a0fc39f60>,
#  'Lou Williams': <__main__.Player at 0x1a0fc48278>,
#  'Luc Richard Mbah a Moute': <__main__.Player at 0x1a0fc48550>,
#  'Lucas Nogueira': <__main__.Player at 0x1a0fc48828>,
#  'Luis Montero': <__main__.Player at 0x1a0fc48b00>,
#  'Luke Babbitt': <__main__.Player at 0x1a0fc48dd8>,
#  'Luke Kennard': <__main__.Player at 0x1a0fc570f0>,
#  'Luke Kornet': <__main__.Player at 0x1a0fc573c8>,
#  'Luol Deng': <__main__.Player at 0x1a0fc576a0>,
#  'Malachi Richardson': <__main__.Player at 0x1a0fc57978>,
#  'Malcolm Brogdon': <__main__.Player at 0x1a0fc57c50>,
#  'Malcolm Delaney': <__main__.Player at 0x1a0fc57f28>,
#  'Malcolm Miller': <__main__.Player at 0x1a0fc63240>,
#  'Malik Beasley': <__main__.Player at 0x1a0fc63518>,
#  'Malik Monk': <__main__.Player at 0x1a0fc637f0>,
#  'Mangok Mathiang': <__main__.Player at 0x1a0fc63ac8>,
#  'Manu GinÃ³bili': <__main__.Player at 0x1a0fc63da0>,
#  'MarShon Brooks': <__main__.Player at 0x1a0fc710b8>,
#  'Marc Gasol': <__main__.Player at 0x1a0fc71390>,
#  'Marcin Gortat': <__main__.Player at 0x1a0fc71668>,
#  'Marco Belinelli': <__main__.Player at 0x1a0fc71940>,
#  'Marcus Georges-Hunt': <__main__.Player at 0x1a0fc71c18>,
#  'Marcus Morris': <__main__.Player at 0x1a0fc71ef0>,
#  'Marcus Paige': <__main__.Player at 0x1a0fc80208>,
#  'Marcus Smart': <__main__.Player at 0x1a0fc804e0>,
#  'Mario Chalmers': <__main__.Player at 0x1a0fc807b8>,
#  'Mario Hezonja': <__main__.Player at 0x1a0fc80a90>,
#  'Markel Brown': <__main__.Player at 0x1a0fc80d68>,
#  'Markelle Fultz': <__main__.Player at 0x1a0fc8f080>,
#  'Markieff Morris': <__main__.Player at 0x1a0fc8f358>,
#  'Marquese Chriss': <__main__.Player at 0x1a0fc8f630>,
#  'Marquis Teague': <__main__.Player at 0x1a0fc8f908>,
#  'Marreese Speights': <__main__.Player at 0x1a0fc8fbe0>,
#  'Marshall Plumlee': <__main__.Player at 0x1a0fc8feb8>,
#  'Marvin Williams': <__main__.Player at 0x1a0fc9c1d0>,
#  'Mason Plumlee': <__main__.Player at 0x1a0fc9c4a8>,
#  'Matt Costello': <__main__.Player at 0x1a0fc9c780>,
#  'Matt Williams': <__main__.Player at 0x1a0fc9ca58>,
#  'Matthew Dellavedova': <__main__.Player at 0x1a0fc9cd30>,
#  'Maxi Kleber': <__main__.Player at 0x1a0fcaa048>,
#  'Meyers Leonard': <__main__.Player at 0x1a0fcaa320>,
#  'Michael Beasley': <__main__.Player at 0x1a0fcaa5f8>,
#  'Michael Carter-Williams': <__main__.Player at 0x1a0fcaa8d0>,
#  'Michael Kidd-Gilchrist': <__main__.Player at 0x1a0fcaaba8>,
#  'Mike Conley': <__main__.Player at 0x1a0fcaae80>,
#  'Mike James': <__main__.Player at 0x1a0fcb9198>,
#  'Mike Muscala': <__main__.Player at 0x1a0fcb9470>,
#  'Mike Scott': <__main__.Player at 0x1a0fcb9748>,
#  'Miles Plumlee': <__main__.Player at 0x1a0fcb9a20>,
#  'Milos Teodosic': <__main__.Player at 0x1a0fcb9cf8>,
#  'Milton Doyle': <__main__.Player at 0x1a0fcc7048>,
#  'Mindaugas Kuzminskas': <__main__.Player at 0x1a0fcc72e8>,
#  'Mirza TeletoviÄ\x87': <__main__.Player at 0x1a0fcc75c0>,
#  'Moe Harkless': <__main__.Player at 0x1a0fcc7898>,
#  'Monte Morris': <__main__.Player at 0x1a0fcc7b70>,
#  'Montrezl Harrell': <__main__.Player at 0x1a0fcc7e48>,
#  'Myke Henry': <__main__.Player at 0x1a0fcd5160>,
#  'Myles Turner': <__main__.Player at 0x1a0fcd5438>,
#  'Nate Wolters': <__main__.Player at 0x1a0fcd5710>,
#  'Nazareth Mitrou-Long': <__main__.Player at 0x1a0fcd59e8>,
#  'Nemanja Bjelica': <__main__.Player at 0x1a0fcd5cc0>,
#  'NenÃª': <__main__.Player at 0x1a0fcd5f98>,
#  'Nerlens Noel': <__main__.Player at 0x1a0fce42b0>,
#  'Nick Collison': <__main__.Player at 0x1a0fce4588>,
#  'Nick Young': <__main__.Player at 0x1a0fce4860>,
#  'Nicolas Batum': <__main__.Player at 0x1a0fce4b38>,
#  'Nicolas Brussino': <__main__.Player at 0x1a0fce4e10>,
#  'Nigel Hayes': <__main__.Player at 0x1a0fcf2128>,
#  'Nik Stauskas': <__main__.Player at 0x1a0fcf2400>,
#  'Nikola JokiÄ\x87': <__main__.Player at 0x1a0fcf26d8>,
#  'Nikola MirotiÄ\x87': <__main__.Player at 0x1a0fcf29b0>,
#  'Nikola VuÄ\x8deviÄ\x87': <__main__.Player at 0x1a0fcf2c88>,
#  'Noah Vonleh': <__main__.Player at 0x1a0fcf2f60>,
#  'Norman Powell': <__main__.Player at 0x1a0fd00278>,
#  'OG Anunoby': <__main__.Player at 0x1a0fd00550>,
#  'Okaro White': <__main__.Player at 0x1a0fd00828>,
#  'Omari Johnson': <__main__.Player at 0x1a0fd00b00>,
#  'Omer Asik': <__main__.Player at 0x1a0fd00dd8>,
#  'Omri Casspi': <__main__.Player at 0x1a0fd0f0f0>,
#  'Otto Porter': <__main__.Player at 0x1a0fd0f3c8>,
#  'P.J. Dozier': <__main__.Player at 0x1a0fd0f6a0>,
#  'P.J. Tucker': <__main__.Player at 0x1a0fd0f978>,
#  'Pascal Siakam': <__main__.Player at 0x1a0fd0fc50>,
#  'Pat Connaughton': <__main__.Player at 0x1a0fd0ff28>,
#  'Patrick Beverley': <__main__.Player at 0x1a0fd1c240>,
#  'Patrick McCaw': <__main__.Player at 0x1a0fd1c518>,
#  'Patrick Mills': <__main__.Player at 0x1a0fd1c7f0>,
#  'Patrick Patterson': <__main__.Player at 0x1a0fd1cac8>,
#  'Pau Gasol': <__main__.Player at 0x1a0fd1cda0>,
#  'Paul George': <__main__.Player at 0x1a0fd2a0b8>,
#  'Paul Millsap': <__main__.Player at 0x1a0fd2a390>,
#  'Paul Zipser': <__main__.Player at 0x1a0fd2a668>,
#  'Quincy Acy': <__main__.Player at 0x1a0fd2a940>,
#  'Quincy Pondexter': <__main__.Player at 0x1a0fd2ac18>,
#  'Quinn Cook': <__main__.Player at 0x1a0fd2aef0>,
#  'R.J. Hunter': <__main__.Player at 0x1a0fd39208>,
#  'Rajon Rondo': <__main__.Player at 0x1a0fd394e0>,
#  'Ramon Sessions': <__main__.Player at 0x1a0fd397b8>,
#  'Rashad Vaughn': <__main__.Player at 0x1a0fd39a90>,
#  'Raulzinho Neto': <__main__.Player at 0x1a0fd39d68>,
#  'Raymond Felton': <__main__.Player at 0x1a0fd48080>,
#  'Reggie Bullock': <__main__.Player at 0x1a0fd48358>,
#  'Reggie Hearn': <__main__.Player at 0x1a0fd48630>,
#  'Reggie Jackson': <__main__.Player at 0x1a0fd48908>,
#  'Richard Jefferson': <__main__.Player at 0x1a0fd48be0>,
#  'Richaun Holmes': <__main__.Player at 0x1a0fd48eb8>,
#  'Ricky Rubio': <__main__.Player at 0x1a0fd561d0>,
#  'Robert Covington': <__main__.Player at 0x1a0fd564a8>,
#  'Robin Lopez': <__main__.Player at 0x1a0fd56780>,
#  'Rodney Hood': <__main__.Player at 0x1a0fd56a58>,
#  'Rodney McGruder': <__main__.Player at 0x1a0fd56d30>,
#  'Rodney Purvis': <__main__.Player at 0x1a0fd64048>,
#  'Ron Baker': <__main__.Player at 0x1a0fd64320>,
#  'Rondae Hollis-Jefferson': <__main__.Player at 0x1a0fd645f8>,
#  "Royce O'Neale": <__main__.Player at 0x1a0fd648d0>,
#  'Rudy Gay': <__main__.Player at 0x1a0fd64ba8>,
#  'Rudy Gobert': <__main__.Player at 0x1a0fd64e80>,
#  'Russell Westbrook': <__main__.Player at 0x1a0fd72198>,
#  'Ryan Anderson': <__main__.Player at 0x1a0fd72470>,
#  'Ryan Arcidiacono': <__main__.Player at 0x1a0fd72748>,
#  'Salah Mejri': <__main__.Player at 0x1a0fd72a20>,
#  'Sam Dekker': <__main__.Player at 0x1a0fd72cf8>,
#  'Scotty Hopson': <__main__.Player at 0x1a0fd80048>,
#  'Sean Kilpatrick': <__main__.Player at 0x1a0fd802e8>,
#  'Semi Ojeleye': <__main__.Player at 0x1a0fd805c0>,
#  'Serge Ibaka': <__main__.Player at 0x1a0fd80898>,
#  'Shabazz Muhammad': <__main__.Player at 0x1a0fd80b70>,
#  'Shabazz Napier': <__main__.Player at 0x1a0fd80e48>,
#  'Shane Larkin': <__main__.Player at 0x1a0fd8e160>,
#  'Shaquille Harrison': <__main__.Player at 0x1a0fd8e438>,
#  'Shaun Livingston': <__main__.Player at 0x1a0fd8e710>,
#  'Shelvin Mack': <__main__.Player at 0x1a0fd8e9e8>,
#  'Sindarius Thornwell': <__main__.Player at 0x1a0fd8ecc0>,
#  'Skal LabissiÃ¨re': <__main__.Player at 0x1a0fd8ef98>,
#  'Solomon Hill': <__main__.Player at 0x1a0fd9c2b0>,
#  'Spencer Dinwiddie': <__main__.Player at 0x1a0fd9c588>,
#  'Stanley Johnson': <__main__.Player at 0x1a0fd9c860>,
#  'Stephen Curry': <__main__.Player at 0x1a0fd9cb38>,
#  'Sterling Brown': <__main__.Player at 0x1a0fd9ce10>,
#  'Steven Adams': <__main__.Player at 0x1a0fdab128>,
#  'T.J. Leaf': <__main__.Player at 0x1a0fdab400>,
#  'T.J. McConnell': <__main__.Player at 0x1a0fdab6d8>,
#  'T.J. Warren': <__main__.Player at 0x1a0fdab9b0>,
#  'Taj Gibson': <__main__.Player at 0x1a0fdabc88>,
#  'Tarik Black': <__main__.Player at 0x1a0fdabf60>,
#  'Taurean Prince': <__main__.Player at 0x1a0fdb9278>,
#  'Terrance Ferguson': <__main__.Player at 0x1a0fdb9550>,
#  'Terrence Ross': <__main__.Player at 0x1a0fdb9828>,
#  'Terry Rozier': <__main__.Player at 0x1a0fdb9b00>,
#  'Thabo Sefolosha': <__main__.Player at 0x1a0fdb9dd8>,
#  'Thaddeus Young': <__main__.Player at 0x1a0fdc70f0>,
#  'Thomas Bryant': <__main__.Player at 0x1a0fdc73c8>,
#  'Thon Maker': <__main__.Player at 0x1a0fdc76a0>,
#  'Tim Frazier': <__main__.Player at 0x1a0fdc7978>,
#  'Tim Hardaway Jr.': <__main__.Player at 0x1a0fdc7c50>,
#  'Tim Quarterman': <__main__.Player at 0x1a0fdc7f28>,
#  'Timofey Mozgov': <__main__.Player at 0x1a0fdd5240>,
#  'TimothÃ© Luwawu-Cabarrot': <__main__.Player at 0x1a0fdd5518>,
#  'Tobias Harris': <__main__.Player at 0x1a0fdd57f0>,
#  'TomÃ¡Å¡ SatoranskÃ½': <__main__.Player at 0x1a0fdd5ac8>,
#  'Tony Allen': <__main__.Player at 0x1a0fdd5da0>,
#  'Tony Bradley': <__main__.Player at 0x1a0fde40b8>,
#  'Tony Parker': <__main__.Player at 0x1a0fde4390>,
#  'Tony Snell': <__main__.Player at 0x1a0fde4668>,
#  'Torrey Craig': <__main__.Player at 0x1a0fde4940>,
#  'Travis Wear': <__main__.Player at 0x1a0fde4c18>,
#  'Treveon Graham': <__main__.Player at 0x1a0fde4ef0>,
#  'Trevor Ariza': <__main__.Player at 0x1a0fdf3208>,
#  'Trevor Booker': <__main__.Player at 0x1a0fdf34e0>,
#  'Trey Burke': <__main__.Player at 0x1a0fdf37b8>,
#  'Trey Lyles': <__main__.Player at 0x1a0fdf3a90>,
#  'Trey McKinney-Jones': <__main__.Player at 0x1a0fdf3d68>,
#  'Tristan Thompson': <__main__.Player at 0x1a0fe010b8>,
#  'Troy Daniels': <__main__.Player at 0x1a0fe01358>,
#  'Troy Williams': <__main__.Player at 0x1a0fe01630>,
#  'Tyler Cavanaugh': <__main__.Player at 0x1a0fe01908>,
#  'Tyler Dorsey': <__main__.Player at 0x1a0fe01be0>,
#  'Tyler Ennis': <__main__.Player at 0x1a0fe01eb8>,
#  'Tyler Johnson': <__main__.Player at 0x1a0fe0f1d0>,
#  'Tyler Lydon': <__main__.Player at 0x1a0fe0f4a8>,
#  'Tyler Ulis': <__main__.Player at 0x1a0fe0f780>,
#  'Tyler Zeller': <__main__.Player at 0x1a0fe0fa58>,
#  'Tyreke Evans': <__main__.Player at 0x1a0fe0fd30>,
#  'Tyrone Wallace': <__main__.Player at 0x1a0fe1d048>,
#  'Tyson Chandler': <__main__.Player at 0x1a0fe1d320>,
#  'Tyus Jones': <__main__.Player at 0x1a0fe1d5f8>,
#  'Udonis Haslem': <__main__.Player at 0x1a0fe1d8d0>,
#  'Vander Blue': <__main__.Player at 0x1a0fe1dba8>,
#  'Victor Oladipo': <__main__.Player at 0x1a0fe1de80>,
#  'Vince Carter': <__main__.Player at 0x1a0fe2b198>,
#  'Vince Hunter': <__main__.Player at 0x1a0fe2b470>,
#  'Wade Baldwin': <__main__.Player at 0x1a0fe2b748>,
#  'Walter Lemon': <__main__.Player at 0x1a0fe2ba20>,
#  'Wayne Ellington': <__main__.Player at 0x1a0fe2bcf8>,
#  'Wayne Selden': <__main__.Player at 0x1a0fe3b048>,
#  'Wes Johnson': <__main__.Player at 0x1a0fe3b2e8>,
#  'Wesley Iwundu': <__main__.Player at 0x1a0fe3b5c0>,
#  'Wesley Matthews': <__main__.Player at 0x1a0fe3b898>,
#  'Will Barton': <__main__.Player at 0x1a0fe3bb70>,
#  'Willie Cauley-Stein': <__main__.Player at 0x1a0fe3be48>,
#  'Willie Reed': <__main__.Player at 0x1a0fe48160>,
#  'Willy HernangÃ³mez': <__main__.Player at 0x1a0fe48438>,
#  'Wilson Chandler': <__main__.Player at 0x1a0fe48710>,
#  'Xavier Munford': <__main__.Player at 0x1a0fe489e8>,
#  'Xavier Rathan-Mayes': <__main__.Player at 0x1a0fe48cc0>,
#  'Xavier Silas': <__main__.Player at 0x1a0fe48f98>,
#  'Yogi Ferrell': <__main__.Player at 0x1a0fe562b0>,
#  'Zach Collins': <__main__.Player at 0x1a0fe56588>,
#  'Zach LaVine': <__main__.Player at 0x1a0fe56860>,
#  'Zach Randolph': <__main__.Player at 0x1a0fe56b38>,
#  'Zaza Pachulia': <__main__.Player at 0x1a0fe56e10>,
#  'Zhou Qi': <__main__.Player at 0x1a0fe66128>,
#  'Ã\x81lex Abrines': <__main__.Player at 0x1a0fe66400>}

# %%
# Team Generating

"""
CONVENTION: A team is represented as a list of player objects
"""
# Out:
# '\nCONVENTION: A team is represented as a list of player objects\n'

# %%
# Model Params / Features Definition

# %%
# Model Training

# %%
# Scenarios
